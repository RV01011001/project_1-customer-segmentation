# %% [markdown]
# # Table of contents
#
# ## 1 Problem Definition & Objectives
#
# This is a transnational dataset that contains all transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based, registered non-store online retail company. The company mainly sells unique all-occasion gifts. Many of the company's customers are wholesalers.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing

# %%
dataset = pd.read_csv('D:/Google Drive/Work/Data Analytics and Data Science/Roadpam/project_1-customer-segmentation/data/raw/e-commerce-data-raw.csv', encoding='latin1')
dataset.head(20)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
dataset.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %% [markdown]
# The data set has 541908 records, and contains the following attributes (columns):
# - InvoiceNo - is a unique identifier assigned to each transaction;
# - StockCode
# - Description
# - Quantity
# - InvoiceDate
# - UnitPrice
# - CustomerID
# - Country
#
# |№|Column name|Column description|
# |---|---|---|
# |1|InvoiceNo|Is a unique identifier assigned to each transaction|
